# %% [markdown]
# # Instructions
#
#
# ● **Preprocess the dataset**
#
# ○ Clean (preprocess all “odd” columns, and pre-process values)
#
# ○ Enrich (get data from grouping operations, maybe enrich in different ways 👀)
#
# ● Perform EDA (exploratory data analysis) on the dataset
#
# ○ Generate visualizations
#
# ○ Share your insights and conclusions
#
# ● Preferably use Python
#
#
# **Open Questions (optional):**
#
# ● Any conclusions based on the number of companies created by date, month, year etc?
#
# ● Does the number of branches for a CNPJ provided on the dataset is equal to the actual
# number produced by the dataset?
#
# ● What about the business activities (CNAE)? What are the main types? Can they be
# aggregated into fewer groups?
#
# ● What are the differences between the cities / zip codes?
#
# ● Is it possible to catch any spatial relationships? Which visualizations would be best in
# this case?
#
# ● If you were to make any model from the data, which one do you think makes sense?

# %% [markdown]
# # Importing libraries and reading data

# %%
#Imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
import pymysql
import pandas_profiling
import re
from datetime import datetime

# %%
df = pd.read_csv('../data/data_case.csv')
# Out:
# /Users/santiagochiesa/.pyenv/versions/3.8.12/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    document_number  cnpj_basico establishment_type  \
# 0    4363642000106      4363642             MATRIZ
# 1   17001584000465     17001584             FILIAL
# 2    6931423000454      6931423             FILIAL
# 3   39842321000179     39842321             MATRIZ
# 4   81671679000223     81671679             FILIAL
#
#                                  razao_social  \
# 0                  TRES GERACOES EM MODA LTDA
# 1  FAGE COMERCIO VAREJISTA DE BIJUTERIAS LTDA
# 2              FONTANA COMERCIO DE JOIAS LTDA
# 3                ZAZULE ESTACAO CURITIBA LTDA
# 4              JOSE PELAYO SANCHEZ & CIA LTDA
#
#                                 nome_fantasia            opening_date  \
# 0                               TRES GERACOES     29 de março de 2001
# 1  FAGE COMERCIO VAREJISTA DE BIJUTERIAS LTDA  20 de setembro de 2018
# 2                                         NaN     30 de julho de 2014
# 3                     ZAZULE ESTACAO CURITIBA  19 de novembro de 2020
# 4                                 PELAYO CASA   09 de outubro de 2013
#
#       cnae                                   cnae_description  \
# 0  4789001  Comércio varejista de suvenires, bijuterias e ...
# 1  4789001  Comércio varejista de suvenires, bijuterias e ...
# 2  4789001  Comércio varejista de suvenires, bijuterias e ...
# 3  4789001  Comércio varejista de suvenires, bijuterias e ...
# 4  4789001  Comércio varejista de suvenires, bijuterias e ...
#
#                          total_branches_and_socios     city_state  city_code  \
# 0  {'tot_socios': 6, 'tot_branches': '1 branches'}  Curitiba - PR    4106902
# 1  {'tot_socios': 7, 'tot_branches': '4 branches'}  Curitiba - PR    4106902
# 2  {'tot_socios': 5, 'tot_branches': '4 branches'}  Curitiba - PR    4106902
# 3  {'tot_socios': 5, 'tot_branches': '1 branches'}  Curitiba - PR    4106902
# 4  {'tot_socios': 5, 'tot_branches': '2 branches'}  Londrina - PR    4113700
#
#    zip_code  capital_social   size_company               juri_description  \
# 0  80410200             0.0   NOT_INFORMED  Sociedade Empresária Limitada
# 1  80610905        100000.0  SMALL_COMPANY  Sociedade Empresária Limitada
# 2  81200240         10000.0   NOT_INFORMED  Sociedade Empresária Limitada
# 3  80230903         10000.0   NOT_INFORMED  Sociedade Empresária Limitada
# 4  86020000         50000.0  SMALL_COMPANY  Sociedade Empresária Limitada
#
#   email_provider
# 0            NaN
# 1    HOTMAIL.COM
# 2            NaN
# 3  ZAZULE.COM.BR
# 4            NaN

# %% [markdown]
# # Data cleaning

# %%
# Checking data types

df.dtypes
# Out:
# document_number                int64
# cnpj_basico                    int64
# establishment_type            object
# razao_social                  object
# nome_fantasia                 object
# opening_date                  object
# cnae                           int64
# cnae_description              object
# total_branches_and_socios     object
# city_state                    object
# city_code                      int64
# zip_code                      object
# capital_social               float64
# size_company                  object
# juri_description              object
# email_provider                object
# dtype: object

# %%
# Checking duplicates

df.duplicated().sum() / len(df)
# Out:
# 0.0

# %%
# Checking nulls

df.isna().sum() / len(df)
# Out:
# document_number              0.000000
# cnpj_basico                  0.000000
# establishment_type           0.000000
# razao_social                 0.000000
# nome_fantasia                0.328898
# opening_date                 0.000000
# cnae                         0.000000
# cnae_description             0.000000
# total_branches_and_socios    0.000000
# city_state                   0.000000
# city_code                    0.000000
# zip_code                     0.000000
# capital_social               0.000000
# size_company                 0.000000
# juri_description             0.000000
# email_provider               0.341263
# dtype: float64

# %%
#Checking column values
for column in df.columns:
    print(df[column].value_counts().head(20))
    print(df[column].value_counts().tail(10))
    print()
    print()
# Out:
# 4363642000106     1
# 38353734000127    1
# 19747444000113    1
# 40390008000126    1
# 40455467000140    1
# 32936513000103    1
# 32551625000138    1
# 31774522000174    1
# 32474742000145    1
# 40275830000146    1
# 41722445000162    1
# 42194867000175    1
# 35678579000120    1
# 21978902000177    1
# 37365409000111    1
# 41894040000101    1
# 31157942000101    1
# 29988808000100    1
# 20879673000170    1
# 29953048000104    1
# Name: document_number, dtype: int64
# 32172944000132    1
# 35032781000180    1
# 19209988000121    1
# 2380579000190     1
# 6168511000101     1
# 25168658000138    1
# 7947121000194     1
# 27153062000190    1
# 17964993000114    1
# 81722795000143    1
# Name: document_number, dtype: int64
#
#
# 15913061    370
# 77500049    156
# 78586674    100
# 75584110     88
# 2905110      86
# 78614278     85
# 2869763      73
# 75923185     66
# 88212113     61
# 11137051     60
# 2031555      60
# 82658840     58
# 33098658     57
# 10302127     57
# 751089       54
# 76189406     54
# 77856995     52
# 2834982      52
# 18192964     49
# 9248166      49
# Name: cnpj_basico, dtype: int64
# 9425106     1
# 8766326     1
# 33115646    1
# 38444785    1
# 3882798     1
# 12903378    1
# 4751729     1
# 988143      1
# 3169386     1
# 81722795    1
# Name: cnpj_basico, dtype: int64
#
#
# MATRIZ    1232586
# FILIAL      49953
# Name: establishment_type, dtype: int64
# MATRIZ    1232586
# FILIAL      49953
# Name: establishment_type, dtype: int64
#
#
# LUCKNOW EMPREENDIMENTOS E PARTICIPACOES LTDA.                          370
# MERCADOMOVEIS LTDA                                                     156
# VIACAO GARCIA LTDA                                                     100
# EXAL - ADMINISTRACAO DE RESTAURANTES EMPRESARIAIS E FACILITIES LTDA     88
# GR SERVICOS E ALIMENTACAO LTDA.                                         86
# COMERCIAL DE MOVEIS BRASILIA LTDA                                       85
# HORFRAN - COMERCIAL ELETRO MOVEIS LTDA                                  73
# VALDAR MOVEIS LTDA                                                      66
# COMERCIO DE MEDICAMENTOS BRAIR LTDA                                     61
# 28 de dezembro de 1978     1
# 28 de dezembro de 1981     1
# 04 de julho de 1972        1
# 30 de maio de 1972         1
# 13 de março de 1952        1
# 22 de novembro de 1969     1
# 26 de agosto de 1985       1
# 02 de julho de 1967        1
# 12 de janeiro de 1983      1
# 11 de fevereiro de 1969    1
# Name: opening_date, dtype: int64
#
#
# 4781400    66146
# 9602501    47121
# 4399103    46573
# 7319002    33861
# 5611203    29552
# 4930202    28486
# 4712100    23139
# 5611201    20565
# 8219999    18033
# 9602502    17535
# 9700500    16579
# 4321500    16313
# 4930201    15869
# 4723700    15618
# 5620104    15506
# 4520001    14874
# 4530703    14207
# 4330404    14141
# 5229099    13978
# 1412601    12697
# Name: cnae, dtype: int64
# 133405     1
# 312404     1
# 2449102    1
# 2092401    1
# 4940000    1
# 2652300    1
# 2442300    1
# 6450600    1
# 729401     1
# 2094100    1
# Name: cnae, dtype: int64
#
#
# Comércio varejista de artigos do vestuário e acessórios                                                                         66146
# Cabeleireiros, manicure e pedicure                                                                                              47121
# Obras de alvenaria                                                                                                              46573
# Promoção de vendas                                                                                                              33861
# Lanchonetes, casas de chá, de sucos e similares                                                                                 29552
# Transporte rodoviário de carga, exceto produtos perigosos e mudanças, intermunicipal, interestadual e internacional             28486
# Comércio varejista de mercadorias em geral, com predominância de produtos alimentícios - minimercados, mercearias e armazéns    23139
# Restaurantes e similares                                                                                                        20565
# Preparação de documentos e serviços especializados de apoio administrativo não especificados anteriormente                      18033
# Atividades de Estética e outros serviços de cuidados com a beleza                                                               17535
# Serviços domésticos                                                                                                             16579
# Instalação e manutenção elétrica                                                                                                16313
# Transporte rodoviário de carga, exceto produtos perigosos e mudanças, municipal                                                 15869
# Comércio varejista de bebidas                                                                                                   15618
# Fornecimento de alimentos preparados preponderantemente para consumo domiciliar                                                 15506
# Serviços de manutenção e reparação mecânica de veículos automotores                                                             14874
# Comércio a varejo de peças e acessórios novos para veículos automotores                                                         14207
# Serviços de pintura de edifícios em geral                                                                                       14141
# Outras atividades auxiliares dos transportes terrestres não especificadas anteriormente                                         13978
# Confecção de peças do vestuário, exceto roupas íntimas e as confeccionadas sob medida                                           12697
# Name: cnae_description, dtype: int64
# Metalurgia dos metais preciosos                                  1
# Resseguros                                                       1
# Sociedades de capitalização                                      1
# Fabricação de tênis de qualquer material                         1
# Extração de minérios de nióbio e titânio                         1
# Cultivo de cítricos, exceto laranja                              1
# Fabricação de adoçantes naturais e artificiais                   1
# Atividades associativas não especificadas anteriormente          1
# Fabricação de locomotivas, vagões e outros materiais rodantes    1
# Fabricação de catalisadores                                      1
# Name: cnae_description, dtype: int64
#
#
# {'tot_socios': 1, 'tot_branches': '1 branches'}    946830
# {'tot_socios': 2, 'tot_branches': '1 branches'}    202952
# {'tot_socios': 3, 'tot_branches': '1 branches'}     24197
# {'tot_socios': 2, 'tot_branches': '2 branches'}     20822
# {'tot_socios': 1, 'tot_branches': '2 branches'}     19686
# {'tot_socios': 4, 'tot_branches': '1 branches'}      8657
# {'tot_socios': 2, 'tot_branches': '3 branches'}      6365
# {'tot_socios': 1, 'tot_branches': '3 branches'}      5224
# {'tot_socios': 3, 'tot_branches': '2 branches'}      3406
# {'tot_socios': 5, 'tot_branches': '1 branches'}      3140
# {'tot_socios': 2, 'tot_branches': '4 branches'}      3017
# {'tot_socios': 1, 'tot_branches': '4 branches'}      2314
# {'tot_socios': 2, 'tot_branches': '5 branches'}      1654
# {'tot_socios': 4, 'tot_branches': '2 branches'}      1480
# {'tot_socios': 3, 'tot_branches': '3 branches'}      1436
# {'tot_socios': 6, 'tot_branches': '1 branches'}      1367
# {'tot_socios': 1, 'tot_branches': '5 branches'}      1261
# {'tot_socios': 2, 'tot_branches': '6 branches'}      1171
# {'tot_socios': 1, 'tot_branches': '6 branches'}       822
# {'tot_socios': 2, 'tot_branches': '7 branches'}       813
# Name: total_branches_and_socios, dtype: int64
# {'tot_socios': 19, 'tot_branches': '5 branches'}     1
# {'tot_socios': 52, 'tot_branches': '2 branches'}     1
# {'tot_socios': 14, 'tot_branches': '14 branches'}    1
# {'tot_socios': 64, 'tot_branches': '3 branches'}     1
# {'tot_socios': 61, 'tot_branches': '1 branches'}     1
# {'tot_socios': 7, 'tot_branches': '41 branches'}     1
# {'tot_socios': 5, 'tot_branches': '55 branches'}     1
# {'tot_socios': 11, 'tot_branches': '59 branches'}    1
# {'tot_socios': 51, 'tot_branches': '3 branches'}     1
# {'tot_socios': 57, 'tot_branches': '1 branches'}     1
# Name: total_branches_and_socios, dtype: int64
#
#
# Curitiba - PR                305883
# Londrina - PR                 71330
# Maringá - PR                  68031
# Cascavel - PR                 40407
# Ponta Grossa - PR             39580
# São José dos Pinhais - PR     38732
# Foz do Iguaçu - PR            33285
# Colombo - PR                  25420
# Pinhais - PR                  18644
# Guarapuava - PR               17380
# Toledo - PR                   17159
# Araucária - PR                14634
# Apucarana - PR                14465
# Arapongas - PR                13859
# Fazenda Rio Grande - PR       13516
# Paranaguá - PR                13424
# Umuarama - PR                 12890
# Campo Mourão - PR             12611
# Campo Largo - PR              12266
# Sarandi - PR                  11319
# Name: city_state, dtype: int64
# Diamante do Sul - PR         130
# Iguatu - PR                  114
# Porto Barreiro - PR          112
# São Manoel do Paraná - PR    110
# Santa Inês - PR              106
# Esperança Nova - PR           96
# Jardim Olinda - PR            94
# Mirador - PR                  91
# Ariranha do Ivaí - PR         79
# Nova Aliança do Ivaí - PR     71
# Name: city_state, dtype: int64
#
#
# 4106902    305883
# 4113700     71330
# 4115200     68031
# 4104808     40407
# 4119905     39580
# 4125506     38732
# 4108304     33285
# 4105805     25420
# 4119152     18644
# 4109401     17380
# 4127700     17159
# 4101804     14634
# 4101408     14465
# 4101507     13859
# 4107652     13516
# 4118204     13424
# 4128104     12890
# 4104303     12611
# 4104204     12266
# 4126256     11319
# Name: city_code, dtype: int64
# 4107124    130
# 4110052    114
# 4120150    112
# 4125555    110
# 4123600    106
# 4107520     96
# 4112603     94
# 4115903     91
# 4101853     79
# 4116505     71
# Name: city_code, dtype: int64
#
#
# 85960000    6031
# 85884000    4956
# 83260000    4707
# 86300000    4629
# 83430000    4599
# 86200000    4570
# 85660000    4421
# 86430000    4280
# 83750000    4270
# 86990000    4225
# 85950000    4086
# 83280000    4062
# 83255000    3859
# 87160000    3621
# 86360000    3561
# 85555000    3550
# 87140000    3546
# 86975000    3544
# 84500000    3539
# 86400000    3515
# Name: zip_code, dtype: int64
# 83055470    1
# 85854210    1
# 85804080    1
# 85601118    1
# 87080360    1
# 87047405    1
# 81030320    1
# 80060200    1
# 85501292    1
# 87035065    1
# Name: zip_code, dtype: int64
#
#
# 1000.0      163046
# 5000.0      148191
# 10000.0     130955
# 0.0         102376
# 1.0         101720
# 20000.0      67602
# 2000.0       53049
# 30000.0      41333
# 100000.0     38932
# 3000.0       38746
# 50000.0      35487
# 15000.0      31119
# 100.0        20649
# 500.0        20006
# 40000.0      15641
# 1500.0       11966
# 4000.0       11489
# 25000.0      11273
# 60000.0       9507
# 6000.0        9180
# Name: capital_social, dtype: int64
# 1471794.0     1
# 2466000.0     1
# 440800.0      1
# 2276000.0     1
# 11078700.0    1
# 9382281.0     1
# 449588.0      1
# 797900.0      1
# 21430.0       1
# 842000.0      1
# Name: capital_social, dtype: int64
#
#
# NOT_INFORMED     1157465
# OTHER              67281
# SMALL_COMPANY      57793
# Name: size_company, dtype: int64
# NOT_INFORMED     1157465
# OTHER              67281
# SMALL_COMPANY      57793
# Name: size_company, dtype: int64
#
#
# Empresário (Individual)                                                     830328
# Sociedade Empresária Limitada                                               371126
# Empresa Individual de Responsabilidade Limitada (de Natureza Empresária)     69592
# Sociedade Simples Limitada                                                   11493
# Name: juri_description, dtype: int64
# Empresário (Individual)                                                     830328
# Sociedade Empresária Limitada                                               371126
# Empresa Individual de Responsabilidade Limitada (de Natureza Empresária)     69592
# Sociedade Simples Limitada                                                   11493
# Name: juri_description, dtype: int64
#
#
# GMAIL.COM              253330
# HOTMAIL.COM            158192
# hotmail.com             87612
# gmail.com               80548
# OUTLOOK.COM             18210
# YAHOO.COM.BR            16042
# yahoo.com.br            10752
# outlook.com              6328
# UOL.COM.BR               5837
# BOL.COM.BR               4954
# uol.com.br               4702
# bol.com.br               4145
# TERRA.COM.BR             3612
# terra.com.br             3601
# CONTABILIZEI.COM.BR      3293
# brturbo.com.br           2995
# LIVE.COM                 2664
# YAHOO.COM                2498
# BRTURBO.COM.BR           2224
# ICLOUD.COM               2176
# Name: email_provider, dtype: int64
# larossi.com.be                1
# LUVICONTABIL.COM.BR           1
# SITIODOCAQUI.COM.BR           1
# USOAR.ES                      1
# LIPEGABI.COM.BR               1
# KRZAK.COM.BR                  1
# ZAZULE.COM.BR                 1
# CHACARAMINASDAGUA.COM.BR      1
# FIUZASISTEMASESITES.COM.BR    1
# EDUEVENTOS.COM.BR             1
# Name: email_provider, dtype: int64

# %% [markdown]
# **Preoprocesing To Do**
#
# document_number: OK.
#
# cnpj_basico: some do not have 8 numbers, should extract from document number.
#
# establishment_type: OK.
#
# razao_social: Some LTDA have dots, other doesn't. Otherwise OK.
#
# nome_fantasia: * and dots might be missing data. 32% nulls. Caps are not consistent.
#
# opening_date: Date is expressed as string.
#
# cnae: OK, probably can be grouped differently.
#
# cnae_description: OK, probably can be grouped differently.
#
# total_branches_and_socios: JSON-Like. tot_socios and tot_branches should be different columns. Only numbers should be extracted.
#
# city_state: OK.
#
# city_code: OK.
#
# zip_code: OK.
#
# capital_social: some 0s and 1s that do not make much sense.
#
# size_company: OK.
#
# juri_description: OK.
#
# email_provider: Caps and names are not consistent, can be grouped better.

# %%
# Correcting cnpj_basico column with the first 8 digits of the document_number

df['cnpj_basico'] = df.document_number.apply(lambda x: int(str(x)[0:8]))

# %%
df['cnpj_basico'].value_counts()
# Out:
# 15913061    370
# 77500049    156
# 78586674    100
# 75584110     88
# 78614278     85
#            ...
# 36808588      1
# 10423294      1
# 12369448      1
# 25307438      1
# 81722795      1
# Name: cnpj_basico, Length: 1238260, dtype: int64

# %%
# Replacing nulls

df.nome_fantasia.fillna('Missing_Name', inplace=True)
df.email_provider.fillna('Missing_Email', inplace=True)

# %%
# Replacing nome_fantasia with odd values

df.loc[df.nome_fantasia=='.', 'nome_fantasia'] = 'Missing_Name'
df.loc[df.nome_fantasia=='***', 'nome_fantasia'] = 'Missing_Name'
df.loc[df.nome_fantasia=='****', 'nome_fantasia'] = 'Missing_Name'
df.loc[df.nome_fantasia=='*****', 'nome_fantasia'] = 'Missing_Name'
df.loc[df.nome_fantasia=='******', 'nome_fantasia'] = 'Missing_Name'
df.loc[df.nome_fantasia=='*******', 'nome_fantasia'] = 'Missing_Name'
df.loc[df.nome_fantasia=='********', 'nome_fantasia'] = 'Missing_Name'

# %%
# Modifying dates

# Extracting year
df.opening_date[0]

# Extracting day 

# Extracting month

# Replacing month by number with dictionary (?)
# Out:
# '29 de março de 2001'

# %%
# Extracting date year
df['opening_year'] = df.opening_date.apply(lambda x: x[-4:])

# %%
# Extracting date day
df['opening_day'] = df.opening_date.apply(lambda x: x[0:2])

# %%
# Extracting date month
df['opening_month']= df.opening_date.apply(lambda x: "".join(re.findall("[a-zA-Z]+", x)).strip('de'))

# %%
# Creating month names list
month_names = list(df.opening_month.value_counts().index)

# %%
# Creating month numbers list
month_numbers= ['03', '05', '02', '01', '04', '08', '06', '07', '10', '09', '11', '12']

# %%
# Creating function to replace values
def replacer(to_replace, list_1, list_2):
    for i in range(len(list_1)):
        if to_replace == list_1[i]:
            to_replace = list_2[i]
    return to_replace

# %%
# Testing function
foo = 'julho'
replacer(foo, month_names, month_numbers)
# Out:
# '07'

# %%
# Replacing month names for numbers
df['opening_month'] = df.opening_month.apply(lambda x: replacer(x, month_names, month_numbers))

# %%
# Creating clean date column
df['opening_date_clean'] = df.opening_year + '/' + df.opening_month + '/' + df.opening_day

# %%
# Changing to date time format
df['opening_date_clean'] = df['opening_date_clean'].apply(lambda x: datetime.strptime(x, '%Y/%m/%d'))

# %%
df
# Out:
#          document_number  cnpj_basico establishment_type  \
# 0          4363642000106     43636420             MATRIZ
# 1         17001584000465     17001584             FILIAL
# 2          6931423000454     69314230             FILIAL
# 3         39842321000179     39842321             MATRIZ
# 4         81671679000223     81671679             FILIAL
# ...                  ...          ...                ...
# 1282534    3535330000250     35353300             FILIAL
# 1282535    3535330000412     35353300             FILIAL
# 1282536    4186294000149     41862940             MATRIZ
# 1282537    4186294000220     41862940             FILIAL
# 1282538   81722795000143     81722795             MATRIZ
#
#                                            razao_social  \
# 0                            TRES GERACOES EM MODA LTDA
# 1            FAGE COMERCIO VAREJISTA DE BIJUTERIAS LTD
# ...            ...       ...             ...            ...
# 1282534    4120804  83420000      12437843.0          OTHER
# 1282535    4120804  83420000      12437843.0          OTHER
# 1282536    4113205  83750000        550000.0  SMALL_COMPANY
# 1282537    4104204  83604365        550000.0  SMALL_COMPANY
# 1282538    4106209  83730000             0.0   NOT_INFORMED
#
#                       juri_description          email_provider opening_year  \
# 0        Sociedade Empresária Limitada           Missing_Email         2001
# 1        Sociedade Empresária Limitada             HOTMAIL.COM         2018
# 2        Sociedade Empresária Limitada           Missing_Email         2014
# 3        Sociedade Empresária Limitada           ZAZULE.COM.BR         2020
# 4        Sociedade Empresária Limitada           Missing_Email         2013
# ...                                ...                     ...          ...
# 1282534  Sociedade Empresária Limitada           Missing_Email         2011
# 1282535  Sociedade Empresária Limitada  AEQAEROESPACIAL.COM.BR         2019
# 1282536  Sociedade Empresária Limitada          CWIAGRO.COM.BR         2000
# 1282537  Sociedade Empresária Limitada          CWIAGRO.COM.BR         2016
# 1282538  Sociedade Empresária Limitada           Missing_Email         1990
#
#         opening_day opening_month opening_date_clean
# 0                29            03         2001-03-29
# 1                20            09         2018-09-20
# 2                30            07         2014-07-30
# 3                19            11         2020-11-19
# 4                09            10         2013-10-09
# ...             ...           ...                ...
# 1282534          27            07         2011-07-27
# 1282535          31            07         2019-07-31
# 1282536          12            12         2000-12-12
# 1282537          13            09         2016-09-13
# 1282538          10            01         1990-01-10
#
# [1282539 rows x 20 columns]

# %%
# Creating total socios and total branches columns

df['total_socios'] = df.total_branches_and_socios.apply(lambda x: re.findall(r'\d+', x)[0])

df['total_branches'] = df.total_branches_and_socios.apply(lambda x: re.findall(r'\d+', x)[1])

# %%
df
# Out:
#          document_number  cnpj_basico establishment_type  \
# 0          4363642000106     43636420             MATRIZ
# 1         17001584000465     17001584             FILIAL
# 2          6931423000454     69314230             FILIAL
# 3         39842321000179     39842321             MATRIZ
# 4         81671679000223     81671679             FILIAL
# ...                  ...          ...                ...
# 1282534    3535330000250     35353300             FILIAL
# 1282535    3535330000412     35353300             FILIAL
# 1282536    4186294000149     41862940             MATRIZ
# 1282537    4186294000220     41862940             FILIAL
# 1282538   81722795000143     81722795             MATRIZ
#
#                                            razao_social  \
# 0                            TRES GERACOES EM MODA LTDA
# 1            FAGE COMERCIO VAREJISTA DE BIJUTERIAS LTDA
# 2                        FONTANA COMERCIO DE JOIAS LTDA
# 3                          ZAZULE ESTACAO CURITIBA LTDA
# 4                        JOSE PELAYO SANCHEZ & CIA LTDA
# ...                                                 ...
# 1282534                  AEQ ALIANCA ELETROQUIMICA LTDA
# 1282535                  AEQ ALIANCA ELETROQUIMICA LTDA
# 1282536                         CWI AGRO FRUTICOLA LTDA
# 1282537                         CWI AGRO FRUTICOLA LTDA
# 1282538  F B C FABRICA BRASILEIRA DE CATALIZADORES LTDA
#
#                                       nome_fantasia            opening_date  \
# 0                                     TRES GERACOES     29 de março de 2001
# 1        FAGE COMERCIO VAREJISTA DE BIJUTERIAS LTD
#
#         opening_date_clean total_socios total_branches
# 0               2001-03-29            6              1
# 1               2018-09-20            7              4
# 2               2014-07-30            5              4
# 3               2020-11-19            5              1
# 4               2013-10-09            5              2
# ...                    ...          ...            ...
# 1282534         2011-07-27            3              4
# 1282535         2019-07-31            3              4
# 1282536         2000-12-12            3              2
# 1282537         2016-09-13            3              2
# 1282538         1990-01-10            4              1
#
# [1282539 rows x 22 columns]

# %%
# Uppercasing email provider's column
df.email_provider = df.email_provider.apply(lambda x: x.upper())

# %%
# Creating a new column only with the email provider's company nam

df['email_provider_company'] = df.email_provider.apply(lambda x: x.split('.')[0])

# %%
df
# Out:
#          document_number  cnpj_basico establishment_type  \
# 0          4363642000106     43636420             MATRIZ
# 1         17001584000465     17001584             FILIAL
# 2          6931423000454     69314230             FILIAL
# 3         39842321000179     39842321             MATRIZ
# 4         81671679000223     81671679             FILIAL
# ...                  ...          ...                ...
# 1282534    3535330000250     35353300             FILIAL
# 1282535    3535330000412     35353300             FILIAL
# 1282536    4186294000149     41862940             MATRIZ
# 1282537    4186294000220     41862940             FILIAL
# 1282538   81722795000143     81722795             MATRIZ
#
#                                            razao_social  \
# 0                            TRES GERACOES EM MODA LTDA
# 1            FAGE COMERCIO VAREJISTA DE BIJUTERIAS LTDA
# 2                        FONTANA COMERCIO DE JOIAS LTDA
# 3                          ZAZULE ESTACAO CURITIBA LTDA
# 4                        JOSE PELAYO SANCHEZ & CIA LTDA
# ...                                                 ...
# 1282534                  AEQ ALIANCA ELETROQUIMICA LTDA
# 1282535                  AEQ ALIANCA ELETROQUIMICA LTDA
# 1282536                         CWI AGRO FRUTICOLA LTDA
# 1282537                         CWI AGRO FRUTICOLA LTDA
# 1282538  F B C FABRICA BRASILEIRA DE CATALIZADORES LTDA
#
#                                       nome_fantasia            opening_date  \
# 0                                     TRES GERACOES     29 de março de 2001
# 1        FAGE COMERCIO VAREJISTA DE BIJUTERIAS LTDA  20 de setembro de 2018
# 2                                      Missing_Name     30 de julho de 2014
# 3                           ZAZULE ESTACAO CURITIBA  19 de novembro de 2020
# 4                                       PELAYO CASA   09 de outubro de 2013
# ...                                             ...                     ...
# 1282534                                Missing_Name     27 de julho de 2011
# 1282535                                Missing_Name     31 de julho de 2019
# 1282536                            CWI AGRO & FRUTI  12 de dezembro de 2000
# 1282537                            CWI AGRO & FRUTI  13 de setembro de 2016
# 1282538                                Missing_Name   10 de janeiro de 1990
#
#             cnae                                   cnae_description  \
# 0        4789001  Comércio varejista de suvenires, bijuterias e ...
# 1        4789001  Comércio varejista de suvenires, bijuterias e ...
# 2        4789001  Comércio varejista de suvenires, bijuterias e ...
# 3        4789001  Comércio varejista de suvenires, bijuterias e ...
# 4        4789001  Comércio varejista de suvenires, bijuterias e ...
# ...          ...                                                ...
# 1282534  2550101  Fabricação de equipamento bélico pesado, excet...
# 1282535  2550101  Fabricação de equipamento bélico pesado, excet...
# 1282536   133411                                 Cultivo de pêssego
# 1282537   133411                                 Cultivo de pêssego
# 1282538  2094100                        Fabricação de catalisadores
#
#                                total_branches_and_socios          city_state  \
# 0        {'tot_socios': 6, 'tot_branches': '1 branches'}       Curitiba - PR
# 1        {'tot_socios': 7, 'tot_branches': '4 branches'}       Curitiba - PR
# 2        {'tot_socios': 5, 'tot_branches': '4 branches'}       Curitiba - PR
# 3        {'tot_socios': 5, 'tot_branches': '1 branches'}       Curitiba - PR
# 4        {'tot_socios': 5, 'tot_branches': '2 branches'}       Londrina - PR
# ...                                                  ...                 ...
# 1282534  {'tot_socios': 3, 'tot_branches': '4 branches'}  Quatro Barras - PR
# 1282535  {'tot_socios': 3, 'tot_branches': '4 branches'}  Quatro Barras - PR
# 1282536  {'tot_socios': 3, 'tot_branches': '2 branches'}           Lapa - PR
# 1282537  {'tot_socios': 3, 'tot_branches': '2 branches'}    Campo Largo - PR
# 1282538  {'tot_socios': 4, 'tot_branches': '1 branches'}       Contenda - PR
#
#          ...   size_company               juri_description  \
# 0        ...   NOT_INFORMED  Sociedade Empresária Limitada
# 1        ...  SMALL_COMPANY  Sociedade Empresária Limitada
# 2        ...   NOT_INFORMED  Sociedade Empresária Limitada
# 3        ...   NOT_INFORMED  Sociedade Empresária Limitada
# 4        ...  SMALL_COMPANY  Sociedade Empresária Limitada
# ...      ...            ...                            ...
# 1282534  ...          OTHER  Sociedade Empresária Limitada
# 1282535  ...          OTHER  Sociedade Empresária Limitada
# 1282536  ...  SMALL_COMPANY  Sociedade Empresária Limitada
# 1282537  ...  SMALL_COMPANY  Sociedade Empresária Limitada
# 1282538  ...   NOT_INFORMED  Sociedade Empresária Limitada
#
#                  email_provider opening_year opening_day opening_month  \
# 0                 MISSING_EMAIL         2001          29            03
# 1                   HOTMAIL.COM         2018          20            09
# 2                 MISSING_EMAIL         2014          30            07
# 3                 ZAZULE.COM.BR         2020          19            11
# 4                 MISSING_EMAIL         2013          09            10
# ...                         ...          ...         ...           ...
# 1282534           MISSING_EMAIL         2011          27            07
# 1282535  AEQAEROESPACIAL.COM.BR         2019          31            07
# 1282536          CWIAGRO.COM.BR         2000          12            12
# 1282537          CWIAGRO.COM.BR         2016          13            09
# 1282538           MISSING_EMAIL         1990          10            01
#
#         opening_date_clean total_socios total_branches email_provider_company
# 0               2001-03-29            6              1          MISSING_EMAIL
# 1               2018-09-20            7              4                HOTMAIL
# 2               2014-07-30            5              4          MISSING_EMAIL
# 3               2020-11-19            5              1                 ZAZULE
# 4               2013-10-09            5              2          MISSING_EMAIL
# ...                    ...          ...            ...                    ...
# 1282534         2011-07-27            3              4          MISSING_EMAIL
# 1282535         2019-07-31            3              4        AEQAEROESPACIAL
# 1282536         2000-12-12            3              2                CWIAGRO
# 1282537         2016-09-13            3              2                CWIAGRO
# 1282538         1990-01-10            4              1          MISSING_EMAIL
#
# [1282539 rows x 23 columns]

# %% [markdown]
# # Data Enrichment

# %%
# Grouping by month-year

# Grouping by economic activity

# Grouping by zip_code or city

# Grouping by capital levels

# Grouping by cnpj básico (Company)

# Adding economic data (Actividad Económica, Consumo, Precios Commodities: Azucar, Soja, Maiz, Trigo, Cafe)

# %%
# Indicators

# Openings per month, social activity, zipcode or city

# Capital per month, avg capital per company

# Average socios, branches per company

# Big companies openings over total openings
